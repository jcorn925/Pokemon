# %%
#Pokemon name image
print('''
                                  ,'\\
    _.----.        ____         ,'  _\\   ___    ___     ____
_,-'       `.     |    |  /`.   \,-'    |   \  /   |   |    \  |`.
\\      __    \\    '-.  | /   `.  ___    |    \\/    |   '-.   \\ |  |
 \\.    \ \   |  __  |  |/    ,','_  `.  |          | __  |    \|  |
   \\    \\/   /,' _`.|      ,' / / / /   |          ,' _`.|     |  |
    \\     ,-'/  /   \    ,'   | \/ / ,`.|         /  /   \  |     |
     \\    \\ |   \_/  |   `-.  \\    `'  /|  |    ||   \_/  | |\\    |
      \\    \\ \\      /       `-.`.___,-' |  |\  /| \      /  | |   |
       \\    \\ `.__,'|  |`-._    `|      |__| \/ |  `.__,'|  | |   |
        \\_.-'       |__|    `-._ |              '-.|     '-.| |   |
                                `'                            '-._|
      ''')  


user_hand = []
#Start Screen
user1 = input(("Enter Your Name: \n"))
print ("\nWelcome", user1, "to the wonderful world of Pokemon\n")
print ("Defeat your opponent to become the Pokemon Master!\n")
#Choose Computers Name
opponent = input(("Choose your opponent's name: \n"))
print("Your opponent is", opponent)
#Computer choices list 
pokemon = ['Charmander','NineTails', 'Ponyta', 'Bulbasaur', 'Bellsprout', 'Oddish', 'Squirtle', 'Psyduck', 'Polywag']
type_1 = ['Fire','Fire','Fire','Grass','Grass','Grass','Water','Water','Water']
print("\nYou will choose three pokemon to battle", opponent)
print("\nHere is a view of the pokemon you will select")
print("-----------------------------------------------------------------------------\n")
print ("Fire: Charmander (25HP|70AP)  Fire: NineTails (30HP|50AP)  Fire: Ponyta (40HP|60AP)\n")
print ("Grass: Bulbasaur (60HP|40AP)  Grass: Bellsprout (40HP|60AP)  Grass: Oddish (50HP|50AP)\n")
print ("Water: Squirtle (80HP|20AP)  Water: Psyduck (70HP|40AP)   Water: Polywag(50HP|50AP)")
print("-----------------------------------------------------------------------------\n")
print("\n\n")
print("----------------------------------")
print("Please select your starter pokemon")
print("\n#1 " + pokemon[0] + "| Type: " + type_1[0])
print("\n#2 " + pokemon[1] + "| Type: " + type_1[1])
print("\n#3 " + pokemon[2] + "| Type: " + type_1[2])
print("\n#4 " + pokemon[3] + "| Type: " + type_1[3])
print("\n#5 " + pokemon[4] + "| Type: " + type_1[4])
print("\n#6 " + pokemon[5] + "| Type: " + type_1[5])
print("\n#7 " + pokemon[6] + "| Type: " + type_1[6])
print("\n#8 " + pokemon[7] + "| Type: " + type_1[7])
print("\n#9 " + pokemon[8] + "| Type: " + type_1[8])
while True:
  starter = input("Which number pokemon would you like to start with \n")
  if starter == "1":
    print(pokemon[0]+ " a great choice!\n")
    starter = pokemon[0]
    user_hand.append(starter)
    break
  elif starter == "2":
    print(pokemon[1]+ " a great choice!\n")
    starter = pokemon[1]
    user_hand.append(starter)
    break
  elif starter == "3":
    print(pokemon[2]+ " a great choice!\n")
    starter = pokemon[2]
    user_hand.append(starter)
    break
  elif starter == "4":
    print(pokemon[3]+ " a great choice!\n")
    starter = pokemon[3]
    user_hand.append(starter)
    break
  elif starter == "5":
    print(pokemon[4]+ " a great choice!\n")
    starter = pokemon[4]
    user_hand.append(starter)
    break
  elif starter == "6":
    print(pokemon[5]+ " a great, yet odd choice\n")
    starter = pokemon[5]
    user_hand.append(starter)
    break
  elif starter == "7":
    print(pokemon[6]+ " a great choice!\n")
    starter = pokemon[6]
    user_hand.append(starter)
    break
  elif starter == "8":
    print(pokemon[7]+ " a great choice!\n")
    starter = pokemon[7]
    user_hand.append(starter)
    break
  elif starter == "9":
    print(pokemon[8]+ " a great choice!\n")
    starter = pokemon[8]
    user_hand.append(starter)
    break
while True:
  second_choice = input("Please select your second pokemon \n")
  if second_choice == "1":
    print(pokemon[0]+ " excellent choice\n")
    second_choice = pokemon[0]
    user_hand.append(second_choice)  
    break   
  elif second_choice == "2":
    print(pokemon[1]+ " excellent choice\n")
    second_choice = pokemon[1]  
    user_hand.append(second_choice) 
    break
  elif second_choice == "3":
    print(pokemon[2]+ " excellent choice\n")
    second_choice = pokemon[2]  
    user_hand.append(second_choice) 
    break
  elif second_choice == "4":
    print(pokemon[3]+ " excellent choice\n")
    second_choice = pokemon[3]  
    user_hand.append(second_choice) 
    break 
  elif second_choice == "5":
    print(pokemon[4]+ " excellent choice\n")
    second_choice = pokemon[4]  
    user_hand.append(second_choice) 
    break
  elif second_choice == "6":
    print(pokemon[5]+ " an excellent, yet odd choice \n")
    second_choice = pokemon[5]  
    user_hand.append(second_choice) 
    break
  elif second_choice == "7":
    print(pokemon[6]+ " excellent choice\n")
    second_choice = pokemon[6] 
    user_hand.append(second_choice)  
    break 
  elif second_choice == "8":
    print(pokemon[7]+ " excellent choice\n")
    second_choice = pokemon[7]  
    user_hand.append(second_choice) 
    break
  elif second_choice == "9":
    print(pokemon[8]+ " excellent choice\n")
    second_choice = pokemon[8]  
    user_hand.append(second_choice) 
    break
while True: 
  third_choice = input("Now for your final choice \n")
  if third_choice == "1":
    print(pokemon[0]+ " a great choice!\n")
    third_choice = pokemon[0]  
    user_hand.append(third_choice) 
    break
  elif third_choice == "2":
    print(pokemon[1]+ " a great choice!\n")
    third_choice = pokemon[1]  
    user_hand.append(third_choice) 
    break
  elif third_choice == "3":
    print(pokemon[2]+ " a great choice!\n")
    third_choice = pokemon[2]  
    user_hand.append(third_choice) 
    break
  elif third_choice == "4":
    print(pokemon[3]+ " a great choice!\n")
    third_choice = pokemon[3]  
    user_hand.append(third_choice) 
    break
  elif third_choice == "5":
    print(pokemon[4]+ " a great choice!\n")
    third_choice = pokemon[4]  
    user_hand.append(third_choice) 
    break
  elif third_choice == "6":
    print(pokemon[5]+ " a great choice!\n")
    third_choice = pokemon[5]  
    user_hand.append(third_choice) 
    break
  elif third_choice == "7":
    print(pokemon[6]+ " a great choice!\n")
    third_choice = pokemon[6]  
    user_hand.append(third_choice) 
    break
  elif third_choice == "8":
    print(pokemon[7]+ " a great choice!\n")
    third_choice = pokemon[7]  
    user_hand.append(third_choice) 
    break
  elif third_choice == "9":
    print(pokemon[8]+ " a great choice!\n")
    third_choice = pokemon[8]  
    user_hand.append(third_choice) 
    break
for x in range(1):
  pokemon.remove(starter) 
  pokemon.remove(second_choice)
  pokemon.remove(third_choice)
import random
pokemon_2 = pokemon
cpu_hand = []
for x in range(1):
  CPUchoice1 = random.choice(pokemon_2)
  pokemon_2.remove(CPUchoice1)
  cpu_hand.append(CPUchoice1) 

  CPUchoice2 = random.choice(pokemon_2)
  pokemon_2.remove(CPUchoice2)
  cpu_hand.append(CPUchoice2)

  CPUchoice3 = random.choice(pokemon_2)
  pokemon_2.remove(CPUchoice3)
  cpu_hand.append(CPUchoice3) 

print("\n", opponent,"Chooses the Following Three Pokemon:",CPUchoice1,",",CPUchoice2,", and",CPUchoice3)
print("\n",opponent+ "'s starting Pokemon will be:", CPUchoice1)
###################
import time #for sleep/delay functions
import numpy as np
# Create the class
class Pokemon:
    def __init__(self, name, types, moves, EVs, health = '===================='):
        # save variables as attributes
        self.name = name
        self.types = types
        self.moves = moves
        self.attack = EVs['ATTACK']
        self.defense = EVs['DEFENSE']
        self.health = health
        self.bars = 20



    def fight(self, Pokemon2):
        # Allow two pokemon to fight each other

        # Print fight information
        print("Time for battle....\n")
        print(user1, " VS", opponent)
        print("\n\n-----POKEMON BATTLE-----")

        print(f"\n{self.name}")
        print("TYPE/", self.types)
        print("ATTACK/", self.attack)
        print("HP/", self.defense)
        
        print("\nVS")
        print(f"\n{Pokemon2.name}")
        print("TYPE/", Pokemon2.types)
        print("ATTACK/", Pokemon2.attack)
        print("HP/", Pokemon2.defense)
    

        time.sleep(2)

        # Consider type advantages
        version = ['Fire', 'Water', 'Grass']
        for i,k in enumerate(version):
            if self.types == k:
                # Both are same type
                if Pokemon2.types == k:
                    string_1_attack = '\nIts not very effective...'
                    string_2_attack = '\nIts not very effective...'

                # Pokemon2 is STRONG
                if Pokemon2.types == version[(i+1)%3]:
                    Pokemon2.attack *= 2
                    
                    self.attack /= 2
                    
                    string_1_attack = '\nIts not very effective...'
                    string_2_attack = '\nIts super effective!'

                # Pokemon2 is WEAK
                if Pokemon2.types == version[(i+2)%3]:
                    self.attack *= 2
                    
                    Pokemon2.attack /= 2
                    
                    string_1_attack = '\nIts super effective!'
                    string_2_attack = '\nIts not very effective...'


        # Now for the actual fighting...
        # Continue while pokemon still have health
        while (self.bars > 0) and (Pokemon2.bars > 0):
            # Print the health of each pokemon
            print(f"\n{self.name}\t\tHP: \t{self.health}")
            print(f"{Pokemon2.name}\t\tHP: \t{Pokemon2.health}\n")

            print(f"Go {self.name}!")
            for i, x in enumerate(self.moves):
                print(f"{i+1}.", x)
            index = int(input('Pick a move: '))
            print(f"\n{self.name} used {self.moves[index-1]}!")
            time.sleep(1)
            print(string_1_attack)

            # Determine damage
            Pokemon2.bars -= self.attack
            Pokemon2.health = "" 

            # Add back bars plus defense boost
            for j in range(int(Pokemon2.bars+.1*Pokemon2.defense)):
                Pokemon2.health += "="

            time.sleep(1)
            print(f"\n{self.name}\t\tHLTH\t{self.health}")
            print(f"{Pokemon2.name}\t\tHLTH\t{Pokemon2.health}\n")
            time.sleep(.5)

            # Check to see if Pokemon fainted
            if Pokemon2.bars <= 0:
                print("\n..." + Pokemon2.name + ' fainted.')
                break

            # Pokemon2s turn

            print(f"Go {Pokemon2.name}!")
            for i, x in enumerate(Pokemon2.moves):
                print(f"{i+1}.", x)
            index = random.randint(1, 3)
            print(f"\n{Pokemon2.name} used {Pokemon2.moves[index-1]}!")
            time.sleep(1)
            print(string_2_attack)

            # Determine damage
            self.bars -= Pokemon2.attack
            self.health = ""

            # Add back bars plus defense boost
            for j in range(int(self.bars+.1*self.defense)):
                self.health += "="

            time.sleep(1)
            print(f"{self.name}\t\tHLTH\t{self.health}")
            print(f"{Pokemon2.name}\t\tHLTH\t{Pokemon2.health}\n")
            time.sleep(.5)

            # Check to see if Pokemon fainted
            if self.bars <= 0:
                print("\n..." + self.name + ' fainted.')
                print(self.name + "You lost!")
                break

            elif Pokemon2.bars <= 0:
                print("\n..." + Pokemon2.name + ' fainted.')
                print(Pokemon2.name + "lost!")
                break
            
if __name__ == '__main__':
  Charmander = Pokemon('Charmander', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'], {'ATTACK':70, 'DEFENSE': 25})
  NineTails = Pokemon('Ninetails', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'],{'ATTACK': 50, 'DEFENSE':30})
  Ponyta = Pokemon('Ponyta', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'],{'ATTACK':60, 'DEFENSE':40})

  Bulbasaur= Pokemon('Bulbasaur', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':40, 'DEFENSE':60})
  Bellsprout= Pokemon('Bellsprout', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':60, 'DEFENSE':40})
  Oddish = Pokemon('Oddish', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':50, 'DEFENSE':50})

  Squirtle = Pokemon('Squirtle', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':20, 'DEFENSE':80})
  Psyduck = Pokemon('Psyduck', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':70, 'DEFENSE':40})
  Polywag = Pokemon('Polywag', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':50, 'DEFENSE':50})

if starter == 'Charmander':
  starter = Pokemon('Charmander', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'], {'ATTACK':70, 'DEFENSE': 25})
elif starter == 'NineTails':
  starter = Pokemon('Ninetails', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'],{'ATTACK': 50, 'DEFENSE':30})
elif starter == 'Ponyta':
  starter = Pokemon('Ponyta', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'],{'ATTACK':60, 'DEFENSE':40})
elif starter == 'Bulbasaur':
  starter = Pokemon('Bulbasaur', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':40, 'DEFENSE':60})
elif starter == 'Bellsprout':
  starter = Pokemon('Bellsprout', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':60, 'DEFENSE':40})
elif starter == 'Oddish':
  starter = Pokemon('Oddish', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':50, 'DEFENSE':50})
elif starter == 'Squirtle':
  starter = Pokemon('Squirtle', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':20, 'DEFENSE':80})
elif starter == 'Psyduck':
  starter = Pokemon('Psyduck', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':70, 'DEFENSE':40})
elif starter == 'Polywag':
  starter = Pokemon('Polywag', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':50, 'DEFENSE':50})

if second_choice == 'Charmander':
  second_choice = Pokemon('Charmander', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'], {'ATTACK':70, 'DEFENSE': 25})
elif second_choice == 'NineTails':
  second_choice = Pokemon('Ninetails', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'],{'ATTACK': 50, 'DEFENSE':30})
elif second_choice == 'Ponyta':
  second_choice = Pokemon('Ponyta', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'],{'ATTACK':60, 'DEFENSE':40})
elif second_choice == 'Bulbasaur':
  second_choice = Pokemon('Bulbasaur', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':40, 'DEFENSE':60})
elif second_choice == 'Bellsprout':
  second_choice = Pokemon('Bellsprout', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':60, 'DEFENSE':40})
elif second_choice == 'Oddish':
  second_choice = Pokemon('Oddish', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':50, 'DEFENSE':50})
elif second_choice == 'Squirtle':
  second_choice = Pokemon('Squirtle', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':20, 'DEFENSE':80})
elif second_choice == 'Psyduck':
  second_choice = Pokemon('Psyduck', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':70, 'DEFENSE':40})
elif second_choice == 'Polywag':
  second_choice = Pokemon('Polywag', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':50, 'DEFENSE':50})

if third_choice == 'Charmander':
  third_choice = Pokemon('Charmander', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'], {'ATTACK':70, 'DEFENSE': 25})
elif third_choice == 'NineTails':
  third_choice = Pokemon('Ninetails', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'],{'ATTACK': 50, 'DEFENSE':30})
elif third_choice == 'Ponyta':
  third_choice = Pokemon('Ponyta', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'],{'ATTACK':60, 'DEFENSE':40})
elif third_choice == 'Bulbasaur':
  third_choice = Pokemon('Bulbasaur', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':40, 'DEFENSE':60})
elif third_choice == 'Bellsprout':
  third_choice = Pokemon('Bellsprout', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':60, 'DEFENSE':40})
elif third_choice == 'Oddish':
  third_choice = Pokemon('Oddish', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':50, 'DEFENSE':50})
elif third_choice == 'Squirtle':
  third_choice = Pokemon('Squirtle', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':20, 'DEFENSE':80})
elif third_choice == 'Psyduck':
  third_choice = Pokemon('Psyduck', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':70, 'DEFENSE':40})
elif third_choice == 'Polywag':
  third_choice = Pokemon('Polywag', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':50, 'DEFENSE':50})



if CPUchoice1 == 'Charmander':
  CPUchoice1 = Pokemon('Charmander', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'], {'ATTACK':70, 'DEFENSE': 25})
elif CPUchoice1 == 'NineTails':
  CPUchoice1 = Pokemon('Ninetails', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'],{'ATTACK': 50, 'DEFENSE':30})
elif CPUchoice1 == 'Ponyta':
  CPUchoice1 = Pokemon('Ponyta', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'],{'ATTACK':60, 'DEFENSE':40})
elif CPUchoice1 == 'Bulbasaur':
  CPUchoice1 = Pokemon('Bulbasaur', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':40, 'DEFENSE':60})
elif CPUchoice1 == 'Bellsprout':
  CPUchoice1 = Pokemon('Bellsprout', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':60, 'DEFENSE':40})
elif CPUchoice1 == 'Oddish':
  CPUchoice1 = Pokemon('Oddish', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':50, 'DEFENSE':50})
elif CPUchoice1 == 'Squirtle':
  CPUchoice1 = Pokemon('Squirtle', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':20, 'DEFENSE':80})
elif CPUchoice1 == 'Psyduck':
  CPUchoice1 = Pokemon('Psyduck', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':70, 'DEFENSE':40})
elif CPUchoice1 == 'Polywag':
  CPUchoice1 = Pokemon('Polywag', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':50, 'DEFENSE':50})

if CPUchoice2 == 'Charmander':
  CPUchoice2 = Pokemon('Charmander', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'], {'ATTACK':70, 'DEFENSE': 25})
elif CPUchoice2 == 'NineTails':
  CPUchoice2 = Pokemon('Ninetails', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'],{'ATTACK': 50, 'DEFENSE':30})
elif CPUchoice2 == 'Ponyta':
  CPUchoice2 = Pokemon('Ponyta', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'],{'ATTACK':60, 'DEFENSE':40})
elif CPUchoice2 == 'Bulbasaur':
  CPUchoice2 = Pokemon('Bulbasaur', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':40, 'DEFENSE':60})
elif CPUchoice2 == 'Bellsprout':
  CPUchoice2 = Pokemon('Bellsprout', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':60, 'DEFENSE':40})
elif CPUchoice2 == 'Oddish':
  CPUchoice2 = Pokemon('Oddish', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':50, 'DEFENSE':50})
elif CPUchoice2 == 'Squirtle':
  CPUchoice2 = Pokemon('Squirtle', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':20, 'DEFENSE':80})
elif CPUchoice2 == 'Psyduck':
  CPUchoice2 = Pokemon('Psyduck', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':70, 'DEFENSE':40})
elif CPUchoice2 == 'Polywag':
  CPUchoice2 = Pokemon('Polywag', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':50, 'DEFENSE':50})

if CPUchoice3 == 'Charmander':
  CPUchoice3 = Pokemon('Charmander', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'], {'ATTACK':70, 'DEFENSE': 25})
elif CPUchoice3 == 'NineTails':
  CPUchoice3 = Pokemon('Ninetails', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'],{'ATTACK': 50, 'DEFENSE':30})
elif CPUchoice3 == 'Ponyta':
  CPUchoice3 = Pokemon('Ponyta', 'Fire', ['Ember', 'Flame Wheel', 'Fire Punch'],{'ATTACK':60, 'DEFENSE':40})
elif CPUchoice3 == 'Bulbasaur':
  CPUchoice3 = Pokemon('Bulbasaur', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':40, 'DEFENSE':60})
elif CPUchoice3 == 'Bellsprout':
  CPUchoice3 = Pokemon('Bellsprout', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':60, 'DEFENSE':40})
elif CPUchoice3 == 'Oddish':
  CPUchoice3 = Pokemon('Oddish', 'Grass', ['Leaf Storm', 'Mega Drain', 'Razor Leaf'],{'ATTACK':50, 'DEFENSE':50})
elif CPUchoice3 == 'Squirtle':
  CPUchoice3 = Pokemon('Squirtle', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':20, 'DEFENSE':80})
elif CPUchoice3 == 'Psyduck':
  CPUchoice3 = Pokemon('Psyduck', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':70, 'DEFENSE':40})
elif CPUchoice3 == 'Polywag':
  CPUchoice3 = Pokemon('Polywag', 'Water', ['Bubble', 'Hydro Pump', 'Surf',],{'ATTACK':50, 'DEFENSE':50})
########################################## define fight ##########

###switch###
starter.fight(CPUchoice1)
starter.fight(CPUchoice2)
starter.fight(CPUchoice3)
# Out:
#                                   ,'\
#     _.----.        ____         ,'  _\   ___    ___     ____
# _,-'       `.     |    |  /`.   \,-'    |   \  /   |   |    \  |`.
# \      __    \    '-.  | /   `.  ___    |    \/    |   '-.   \ |  |
#  \.    \ \   |  __  |  |/    ,','_  `.  |          | __  |    \|  |
#    \    \/   /,' _`.|      ,' / / / /   |          ,' _`.|     |  |
#     \     ,-'/  /   \    ,'   | \/ / ,`.|         /  /   \  |     |
#      \    \ |   \_/  |   `-.  \    `'  /|  |    ||   \_/  | |\    |
#       \    \ \      /       `-.`.___,-' |  |\  /| \      /  | |   |
#        \    \ `.__,'|  |`-._    `|      |__| \/ |  `.__,'|  | |   |
#         \_.-'       |__|    `-._ |              '-.|     '-.| |   |
#                                 `'                            '-._|
#
#
# Welcome f to the wonderful world of Pokemon
#
# Defeat your opponent to become the Pokemon Master!
#
# Your opponent is g
#
# You will choose three pokemon to battle g
#
# ...
